# %% [markdown]
# # WeatherPy
#
# #Observed Trends
#
# 1.   An observable trend between relationship between maximum temperatures and latitudes is that the temperature tends to linearly increase towards the latitude 20 across the northern and southern hemisphere, peaking at latitude 20 in the northern hemisphere and latitude -20  in the southern hemisphere, rather than reaching a peak at the equator.   Also, there is a strong relationship between temperatures and latitudes, and based on linear regression r-squared values for the best fit are about -0.75 and 0.82 for the northern and southern hemispheres respectively.
# 2.  Upon analysis of geolocation versus humidity heatmap, an observable trend is that coastal areas across the world are more humid (as shown by red dots) than inland areas.  The explanation for this trend is that air absorbs moisture directly from the sea and humidity levels increase as the air get hotter.  An interesting trend is that most of the cities that were a fit to my weather prescripts are concentrated in the Middle East where there is no significant amount of heat marks.
# 3. From the plots cloudiness seem to have no correlation with geolocation.  Clouds are haphazardly spread all over the latitudes across both atmospheres with insignificant negative r-squared values: -0.09 and -0.12 for northern and southern hemisphere respectively.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import json
import urllib
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %%
#OpenWeatherMap API Key
api_key = weather_api_key

#starting URL for Weather map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Define empty lists to store values

city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

#Print to logger
print("Beginning Data Retrieval")
print("------------------------")

#Create counters
record_count = 1
set_count = 1

#Looping through cities to make api calls using city as query
i = 1
for city in cities:
    city=city
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    
    
#Extracting data. Missing data is handled by try and except  
    try:
        city_name.append(response["name"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]['temp_max'])
        humidity.append(response["main"]['humidity'])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"]) 
        print(f"Processing record {i}|{city}")
        i+=1
         
    except (KeyError):
        print("City not found. skipping.")
    
print('''
-----------------------------
Data Retrieval Complete
-----------------------------''')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing record 1|bluff
# Processing record 2|hobart
# City not found. skipping.
# Processing record 3|snasa
# Processing record 4|inta
# Processing record 5|san patricio
# Processing record 6|xiamen
# Processing record 7|mitsamiouli
# Processing record 8|port alfred
# Processing record 9|mahebourg
# Processing record 10|guarapari
# Processing record 11|kenai
# Processing record 12|richards bay
# City not found. skipping.
# Processing record 13|merauke
# Processing record 14|pisco
# Processing record 15|atuona
# Processing record 16|sitka
# Processing record 17|upernavik
# Processing record 18|ribeira grande
# City not found. skipping.
# Processing record 19|avarua
# Processing record 20|castro
# Processing record 21|severo-kurilsk
# Processing record 22|bredasdorp
# Processing record 23|hope
# Processing record 24|kodiak
# Processing record 25|luderitz
# Processing record 26|linxia
# Processing record 27|matay
# Processing record 28|axim
# Processing record 29|lorengau
# Processing record 30|saint george
# Processing record 31|vrangel
# Processing record 32|fukue
# Processing record 33|fortuna
# Processing record 34|albany
# City not found. skipping.
# Processing record 35|vaini
# Processing record 36|ushuaia
# Processing record 37|punta arenas
# Processing record 38|rikitea
# Processing record 39|thunder bay
# Processing record 40|iqaluit
# Processing record 41|ilinskiy
# Processing record 42|saskylakh
# City not found. skipping.
# Processing record 43|padang
# Processing record 44|busselton
# City not found. skipping.
# Processing record 45|hilo
# Processing record 46|vysokogornyy
# Processing record 47|airai
# Processing record 48|visnes
# Processing record 49|zharkent
# Processing record 50|aykhal
# Processing record 51|portel
# Processing record 52|barrow
# Processing record 53|bokoro
# Processing record 54|sao joao da barra
# Processing record 55|vung tau
# Processing record 56|hermanus
# Processing record 57|rawson
# Processing record 58|mataura
# Processing record 59|khatanga
# Processing record 60|znamenskoye
# Processing record 61|ramnagar
# Processing record 62|chaves
# Processing record 63|taoudenni
# Processing record 64|ostrovnoy
# Processing record 65|vanimo
# Processing record 66|cape town
# City not found. skipping.
# Processing record 67|atar
# Processing record 68|tasiilaq
# Processing record 69|yellowknife
# Processing record 70|chara
# Processing record 71|jamestown
# Processing record 72|kahului
# Processing record 73|jiaocheng
# Processing record 74|la ronge
# Processing record 75|mnogovershinnyy
# Processing record 76|tuktoyaktuk
# Processing record 77|itarema
# Processing record 78|thompson
# Processing record 79|banjar
# Processing record 80|ponta do sol
# Processing record 81|fuerte olimpo
# Processing record 82|rypefjord
# Processing record 83|nikolskoye
# City not found. skipping.
# Processing record 84|andenes
# Processing record 85|bac lieu
# Processing record 86|bethel
# Processing record 87|upington
# Processing record 88|kapaa
# Processing record 89|grande prairie
# Processing record 90|belaya gora
# City not found. skipping.
# Processing record 91|dumas
# Processing record 92|jining
# Processing record 93|waterloo
# Processing record 94|chumikan
# Processing record 95|greenwood
# City not found. skipping.
# Processing record 96|cap malheureux
# Processing record 97|new norfolk
# Processing record 98|wajima
# Processing record 99|tiksi
# Processing record 100|zhenhai
# Processing record 101|hithadhoo
# Processing record 102|narsaq
# Processing record 103|niwari
# Processing record 104|aswan
# Processing record 105|hualmay
# Processing record 106|torbay
# Processing record 107|miri
# City not found. skipping.
# Processing record 108|puerto escondido
# City not found. skipping.
# Processing record 109|grand-santi
# Processing record 110|namibe
# Processing record 111|marzuq
# Processing record 112|huarmey
# Processing record 113|puerto ayora
# Processing record 114|isangel
# Processing record 115|lagoa
# Processing record 116|novyy urengoy
# Processing record 117|ambanja
# Processing record 118|namatanai
# Processing record 119|chuy
# City not found. skipping.
# Processing record 120|cayenne
# Processing record 121|qaqortoq
# City not found. skipping.
# Processing record 122|san cristobal
# Processing record 123|pangnirtung
# Processing record 124|bubaque
# Processing record 125|kaeo
# Processing record 126|svetlaya
# Processing record 127|nouadhibou
# Processing record 128|provideniya
# Processing record 129|vardo
# Processing record 130|necochea
# Processing record 131|tuscaloosa
# Processing record 132|ust-uda
# Processing record 133|alice springs
# City not found. skipping.
# Processing record 134|chokurdakh
# Processing record 135|kavieng
# Processing record 136|storm lake
# Processing record 137|helmsdale
# Processing record 138|mehamn
# Processing record 139|emborion
# City not found. skipping.
# Processing record 140|coquimbo
# City not found. skipping.
# Processing record 141|macau
# Processing record 142|severomuysk
# Processing record 143|manicore
# Processing record 144|komsomolskiy
# Processing record 145|beloha
# City not found. skipping.
# Processing record 146|grand gaube
# Processing record 147|casale monferrato
# City not found. skipping.
# Processing record 148|casatenovo
# Processing record 149|katherine
# City not found. skipping.
# Processing record 150|madang
# City not found. skipping.
# Processing record 151|keti bandar
# Processing record 152|dikson
# Processing record 153|boralday
# City not found. skipping.
# Processing record 154|guia de isora
# Processing record 155|great yarmouth
# Processing record 156|magadan
# Processing record 157|pevek
# Processing record 158|nanortalik
# Processing record 159|muravlenko
# Processing record 160|lamar
# Processing record 161|general pico
# Processing record 162|carnarvon
# Processing record 163|brae
# Processing record 164|chase
# Processing record 165|ilulissat
# Processing record 166|kerema
# City not found. skipping.
# Processing record 167|portmore
# Processing record 168|rengali
# Processing record 169|chippewa falls
# City not found. skipping.
# Processing record 170|teplyk
# Processing record 171|cockburn town
# Processing record 172|faanui
# Processing record 173|dingle
# City not found. skipping.
# Processing record 174|touros
# City not found. skipping.
# Processing record 175|port-cartier
# Processing record 176|ixtapa
# City not found. skipping.
# Processing record 177|norman wells
# Processing record 178|khem karan
# Processing record 179|adiake
# Processing record 180|longyearbyen
# Processing record 181|mahon
# Processing record 182|husavik
# Processing record 183|paamiut
# Processing record 184|krasnomayskiy
# Processing record 185|polunochnoye
# City not found. skipping.
# Processing record 186|koslan
# Processing record 187|lompoc
# Processing record 188|auki
# Processing record 189|qasigiannguit
# Processing record 190|ati
# Processing record 191|kyabe
# City not found. skipping.
# Processing record 192|bengkulu
# Processing record 193|laguna
# Processing record 194|caldas novas
# Processing record 195|darnah
# Processing record 196|cabo san lucas
# Processing record 197|portland
# Processing record 198|goure
# Processing record 199|shimoda
# Processing record 200|salinopolis
# Processing record 201|leningradskiy
# Processing record 202|estelle
# Processing record 203|novoagansk
# Processing record 204|beringovskiy
# Processing record 205|petrovsk
# Processing record 206|talnakh
# Processing record 207|san andres
# City not found. skipping.
# Processing record 208|honningsvag
# Processing record 209|luanda
# Processing record 210|arraial do cabo
# Processing record 211|bantogon
# Processing record 212|sola
# Processing record 213|east london
# Processing record 214|nandu
# Processing record 215|port hardy
# Processing record 216|nishihara
# Processing record 217|cidreira
# Processing record 218|tabas
# Processing record 219|arcata
# Processing record 220|supe
# Processing record 221|mazyr
# Processing record 222|georgetown
# Processing record 223|cherskiy
# Processing record 224|tautira
# Processing record 225|slave lake
# Processing record 226|andros town
# Processing record 227|bereda
# Processing record 228|saint-francois
# Processing record 229|siderno
# Processing record 230|alexandria
# Processing record 231|northallerton
# Processing record 232|conceicao do araguaia
# Processing record 233|sur
# Processing record 234|kapit
# Processing record 235|chilakalurupet
# Processing record 236|qaanaaq
# Processing record 237|codrington
# Processing record 238|ardahan
# Processing record 239|poum
# Processing record 240|lebu
# Processing record 241|roma
# City not found. skipping.
# Processing record 242|mount isa
# City not found. skipping.
# Processing record 243|jiangyou
# Processing record 244|butaritari
# Processing record 245|olinda
# Processing record 246|bambous virieux
# Processing record 247|camocim
# Processing record 248|ancud
# Processing record 249|shimanovsk
# Processing record 250|hasaki
# Processing record 251|acapulco
# Processing record 252|katsuura
# Processing record 253|arman
# Processing record 254|kruisfontein
# Processing record 255|saint-philippe
# Processing record 256|sabya
# Processing record 257|nyurba
# City not found. skipping.
# City not found. skipping.
# Processing record 258|te anau
# Processing record 259|plouzane
# Processing record 260|yar-sale
# Processing record 261|okakarara
# Processing record 262|victoria
# Processing record 263|stonehouse
# City not found. skipping.
# Processing record 264|moose factory
# Processing record 265|malanje
# Processing record 266|jumla
# Processing record 267|esperance
# Processing record 268|lazarev
# Processing record 269|kudahuvadhoo
# City not found. skipping.
# Processing record 270|bossangoa
# Processing record 271|kirakira
# Processing record 272|havoysund
# City not found. skipping.
# Processing record 273|walvis bay
# Processing record 274|hurricane
# Processing record 275|sawtell
# Processing record 276|gouyave
# Processing record 277|primo tapia
# Processing record 278|labuhan
# Processing record 279|valparaiso
# Processing record 280|port-gentil
# Processing record 281|quepos
# Processing record 282|kachug
# Processing record 283|resistencia
# Processing record 284|salalah
# Processing record 285|shingu
# Processing record 286|port lincoln
# Processing record 287|lata
# Processing record 288|saint-pierre
# Processing record 289|tessalit
# Processing record 290|chifeng
# Processing record 291|makakilo city
# Processing record 292|inhambane
# Processing record 293|togur
# Processing record 294|carroll
# Processing record 295|emerald
# Processing record 296|mar del plata
# Processing record 297|moerai
# Processing record 298|hami
# Processing record 299|santa vitoria
# Processing record 300|kyzyl-suu
# Processing record 301|otofuke
# Processing record 302|north bend
# Processing record 303|daru
# Processing record 304|port elizabeth
# Processing record 305|alpena
# Processing record 306|santiago del estero
# Processing record 307|bom jesus
# Processing record 308|osa
# Processing record 309|severo-yeniseyskiy
# Processing record 310|kitob
# Processing record 311|mount gambier
# Processing record 312|kaitangata
# Processing record 313|acarau
# Processing record 314|kalmunai
# Processing record 315|palu
# Processing record 316|vurnary
# Processing record 317|sadao
# Processing record 318|santa isabel do rio negro
# Processing record 319|rantauprapat
# Processing record 320|yumen
# Processing record 321|rio gallegos
# Processing record 322|hamilton
# Processing record 323|palmer
# Processing record 324|bandar
# Processing record 325|maua
# Processing record 326|fuyu
# Processing record 327|anloga
# Processing record 328|mizdah
# Processing record 329|dwarka
# Processing record 330|coos bay
# Processing record 331|saldanha
# City not found. skipping.
# Processing record 332|lerwick
# Processing record 333|zhezkazgan
# Processing record 334|north battleford
# Processing record 335|anstruther
# Processing record 336|orlandia
# Processing record 337|bratsk
# Processing record 338|srednekolymsk
# Processing record 339|port augusta
# Processing record 340|korla
# Processing record 341|flinders
# Processing record 342|wamba
# Processing record 343|coihaique
# Processing record 344|vuktyl
# Processing record 345|san joaquin
# Processing record 346|tomatlan
# Processing record 347|porto santo
# Processing record 348|ayan
# Processing record 349|saint-georges
# Processing record 350|pochutla
# Processing record 351|suntar
# Processing record 352|bani
# Processing record 353|namanyere
# Processing record 354|neiafu
# Processing record 355|sept-iles
# Processing record 356|la asuncion
# Processing record 357|bairiki
# Processing record 358|sakakah
# Processing record 359|porto novo
# Processing record 360|aksha
# Processing record 361|jefferson city
# Processing record 362|alta gracia
# Processing record 363|college
# City not found. skipping.
# Processing record 364|port hawkesbury
# Processing record 365|maniitsoq
# Processing record 366|la seyne-sur-mer
# Processing record 367|eureka
# Processing record 368|viseu
# Processing record 369|yarada
# Processing record 370|high level
# Processing record 371|kinkala
# Processing record 372|hobyo
# Processing record 373|myingyan
# Processing record 374|oia
# Processing record 375|klaksvik
# Processing record 376|prince rupert
# City not found. skipping.
# Processing record 377|naigarhi
# Processing record 378|pokhara
# Processing record 379|san felipe
# Processing record 380|fort collins
# Processing record 381|indiaroba
# Processing record 382|griffith
# Processing record 383|mogzon
# Processing record 384|berlevag
# Processing record 385|qusar
# Processing record 386|severnyy
# Processing record 387|athens
# Processing record 388|hit
# Processing record 389|haines junction
# City not found. skipping.
# Processing record 390|telenesti
# Processing record 391|lavrentiya
# Processing record 392|camana
# Processing record 393|qax
# Processing record 394|ouadda
# Processing record 395|nhulunbuy
# Processing record 396|anadyr
# Processing record 397|kavaratti
# Processing record 398|cheremukhovo
# Processing record 399|hay river
# Processing record 400|gardez
# Processing record 401|tsaratanana
# Processing record 402|caravelas
# Processing record 403|mungwi
# Processing record 404|colomi
# Processing record 405|saquena
# Processing record 406|souillac
# Processing record 407|santa maria
# Processing record 408|qingdao
# Processing record 409|christchurch
# City not found. skipping.
# Processing record 410|rehnan
# City not found. skipping.
# Processing record 411|ashland
# Processing record 412|naze
# Processing record 413|monrovia
# Processing record 414|sterling
# Processing record 415|sokoni
# Processing record 416|klyuchi
# Processing record 417|robertsport
# Processing record 418|bulawayo
# Processing record 419|claremore
# Processing record 420|kaya
# City not found. skipping.
# Processing record 421|whitehorse
# Processing record 422|saint-joseph
# Processing record 423|shache
# Processing record 424|djibo
# Processing record 425|natal
# Processing record 426|boguchany
# Processing record 427|trinidad
# Processing record 428|vestmanna
# Processing record 429|abu kamal
# Processing record 430|kalawit
# Processing record 431|tupik
# Processing record 432|tondano
# Processing record 433|petrokamenskoye
# Processing record 434|yinchuan
# Processing record 435|araouane
# Processing record 436|athabasca
# City not found. skipping.
# Processing record 437|gazojak
# Processing record 438|saint-augustin
# Processing record 439|antalaha
# Processing record 440|udachnyy
# Processing record 441|trairi
# Processing record 442|maceio
# Processing record 443|pistsovo
# Processing record 444|port macquarie
# Processing record 445|kalabo
# Processing record 446|yola
# Processing record 447|glace bay
# Processing record 448|wagar
# City not found. skipping.
# Processing record 449|toccoa
# City not found. skipping.
# Processing record 450|grindavik
# Processing record 451|kadiri
# Processing record 452|bafut
# Processing record 453|vila franca do campo
# Processing record 454|tura
# Processing record 455|lafiagi
# Processing record 456|vaitape
# City not found. skipping.
# City not found. skipping.
# Processing record 457|rockport
# Processing record 458|quatre cocos
# Processing record 459|sinnamary
# Processing record 460|loreto
# Processing record 461|pakxan
# Processing record 462|la maddalena
# Processing record 463|tezu
# Processing record 464|pandan
# Processing record 465|indianola
# Processing record 466|lentekhi
# Processing record 467|lima
# Processing record 468|trencin
# Processing record 469|severobaykalsk
# Processing record 470|nemuro
# Processing record 471|totness
# Processing record 472|kos
# Processing record 473|kindu
# Processing record 474|le pont-de-claix
# Processing record 475|ewo
# Processing record 476|flin flon
# Processing record 477|urusha
# Processing record 478|aguilas
# Processing record 479|muscat
# Processing record 480|abu dhabi
# Processing record 481|yumbe
# Processing record 482|las margaritas
# Processing record 483|kirby
# Processing record 484|pitimbu
# Processing record 485|hirara
# Processing record 486|caconda
# Processing record 487|mercedes
# Processing record 488|neepawa
# Processing record 489|zhangye
# Processing record 490|asau
# Processing record 491|arroyo
# Processing record 492|verkhnyaya inta
# Processing record 493|avera
# Processing record 494|chapais
# Processing record 495|wakkanai
# City not found. skipping.
# Processing record 496|las vegas
# Processing record 497|randfontein
# Processing record 498|ratnagiri
# Processing record 499|kamenka
# Processing record 500|killybegs
# City not found. skipping.
# Processing record 501|araucaria
# Processing record 502|stabat
# Processing record 503|wahiawa
# Processing record 504|bayaguana
# Processing record 505|aklavik
# City not found. skipping.
# Processing record 506|yaan
# Processing record 507|santander
# Processing record 508|mahenge
# Processing record 509|san juan
# Processing record 510|bilma
# Processing record 511|trincomalee
# Processing record 512|katobu
# Processing record 513|dongsheng
# Processing record 514|carutapera
# City not found. skipping.
# Processing record 515|baley
# Processing record 516|itupiranga
# Processing record 517|mandiana
# Processing record 518|lalibela
# Processing record 519|williamsburg
# Processing record 520|mosquera
# Processing record 521|chabahar
# Processing record 522|qingyuan
# Processing record 523|deputatskiy
# Processing record 524|kautokeino
# City not found. skipping.
# Processing record 525|lodwar
# Processing record 526|yuxia
# Processing record 527|taybad
# Processing record 528|tuy hoa
# Processing record 529|seminole
# Processing record 530|biak
# Processing record 531|bilibino
# Processing record 532|deniliquin
# Processing record 533|arlit
# Processing record 534|punta cardon
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Turn appended lists into dictionary
weather_dict = {
                "City": cities,
                "Lat": lat,
                "Lng": lng,
                "Max Temp": max_temp,
                "Cloudiness": cloudiness,
                "Humidity": humidity, 
                "Wind Speed": wind_speed,
                "Country": country,
                "Date": date                       
               }
#Turn dictionary into dataframe
city_data = pd.DataFrame({k: pd.Series(l) for k, l in weather_dict.items()})


# export city_data into csv
export_csv = city_data.to_csv (output_data_file, index_label = "City_ID")

# display Dataframe head
city_data.head()
# Out:
#         City      Lat       Lng  Max Temp  Cloudiness  Humidity  Wind Speed  \
# 0      bluff -46.6000  168.3333     49.80        82.0      71.0        1.45
# 1     hobart -42.8794  147.3294     55.02        75.0      92.0        1.01
# 2  angelholm  64.2457   12.3778     54.81        47.0      59.0        2.51
# 3      snasa  66.0317   60.1659     50.95       100.0      67.0        6.04
# 4       inta  28.0170  -97.5169     82.85         6.0      93.0        8.97
#
#   Country          Date
# 0      NZ  1.623301e+09
# 1      AU  1.623301e+09
# 2      NO  1.623301e+09
# 3      RU  1.623301e+09
# 4      US  1.623301e+09

# %%
# drop all the rows in which any of the column contains null value.
city_data = city_data.dropna(how="any")
city_data.count()
# Out:
# City          534
# Lat           534
# Lng           534
# Max Temp      534
# Cloudiness    534
# Humidity      534
# Wind Speed    534
# Country       534
# Date          534
# dtype: int64

# %%
#Exporting data to csv
city_data.to_csv("output_data/cities.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
print("No city with humidity over 100%")
# Out:
# No city with humidity over 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#set todat date
today_date = pd.to_datetime('today').date().strftime('%m/%d/%y')

#Set x and y values
x_values = city_data['Lat']
y_values = city_data['Max Temp']

# Create scatter plot for lats vs temp
plt.scatter(x_values, y_values, edgecolors='black')

#Set Labels
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.title(f"City Latitude vs. Max Temperature ({today_date})")

#save & show
plt.savefig('output_data/LatitudeVsMaxTemp.png')

# %% [markdown]
# The above scatterplot is analyzing temperature values closer and further away from the equator.  Temperatures seem to peak around 20 latitudes and drop as we move away from the 20 latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Set x and y values
x_values = city_data['Lat']
y_values = city_data['Humidity']

# Create scatter plot for lats vs temp
plt.scatter(x_values, y_values, edgecolors='black')

#Set Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"City Latitude vs. Humidity ({today_date})")

#style grid
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#save & show
plt.savefig('output_data/LatitudeVsHumidity.png')

# %% [markdown]
# At first glance it seems there is not relationship between humidity and latitude, but humidity percentages appear to be largely clustered above 50% across the x_axis.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Set x and y values
x_values = city_data['Lat']
y_values = city_data['Cloudiness']

# Create scatter plot for lats vs temp
plt.scatter(x_values, y_values, edgecolors='black')

#Set Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"City Latitude vs. Cloudiness ({today_date})")

#style grid
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#save & show
plt.savefig('output_data/LatitudeVsCloudiness.png')

# %% [markdown]
#  Clouds are widely spread across the latitudes. The scatterplot above does not appear to show a definitive relationship between cloud cover and geolocation.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Set x and y values
x_values = city_data['Lat']
y_values = city_data['Wind Speed']

# Create scatter plot for lats vs temp
plt.scatter(x_values, y_values, edgecolors='black')

#Set Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"City Latitude vs. Wind Speed ({today_date})")

#style grid
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#save & show
plt.savefig('output_data/LatitudeVsWindSpeed.png')

# %% [markdown]
# Wind speed data is clustered  below 20mph across the latitude. The plot does not show any relationship between latitude and wind speed.

# %% [markdown]
# ## Linear Regression

# %%
 def linear_reg_plot(df, title_name, y_column_name, y_label, file_name, xy):
    x_values = df['Lat']
    y_values = df[y_column_name]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.annotate(line_eq,xy,fontsize=15,color="red")
    plt.title(title_name)
    
    print(f"The r-squared is: {rvalue}")
    
    plt.savefig(file_name)

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = city_data.loc[city_data['Lat'] >= 0, :]
southern_hemisphere_df = city_data.loc[city_data['Lat'] < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Max Temp Vs Latitude Regression', 'Max Temp', 'Max Temp', 'output_data/NorthernMaxTempVsLatitudeReg.png', (10,0))
# Out:
# The r-squared is: -0.7472595978305326

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Max Temp Vs Latitude Regression', 'Max Temp', 'Max Temp', 'output_data/SouthernMaxTempVsLatitudeReg.png', (-40,50))
# Out:
# The r-squared is: 0.8145110530022359

# %% [markdown]
# Both hemispheres show strong correlations (negative for the northern hemisphere and positive hemisphere) between maximum temperatures and latitudes.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Humidity Vs. Latitude Regression', 'Humidity', 'Humidity', 'output_data/NorthernHumidityVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: -0.09236281433412984

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Humidity Vs. Latitude Regression', 'Humidity', 'Humidity', 'output_data/SouthernHumidityVsLatitudeReg.png', (-50,20))
# Out:
# The r-squared is: -0.12320076442403502

# %% [markdown]
# Neither hemispheres display strong correlations between humidity levels and latitudes. geolocation. Scores indicate the variability cannot be predicted by the line of best fit.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Cloudiness Vs. Latitude Regression', 'Cloudiness', 'Cloudiness', 'output_data/NorthernCloudinessVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: 0.029572282026305706

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Cloudiness Vs. Latitude Regression', 'Cloudiness', 'Cloudiness', 'output_data/SouthernCloudinessVsLatitudeReg.png', (-50,20))
# Out:
# The r-squared is: -0.14632159966183042

# %% [markdown]
# Neither hemisphere display a strong correlations between cloudiness and latitudes. Scores indicate that the variability cannot be predicted by the line of best fit.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Wind Speed Vs. Latitude Regression', 'Wind Speed', 'Wind Speed', 'output_data/NorthernWindSpeedVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: 0.15333398597348014

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Wind Speed Vs. Latitude', 'Wind Speed', 'Wind Speed', 'output_data/SouthernWindSpeedVsLatitudeReg.png', (-30,20))
# Out:
# The r-squared is: -0.0215045923172799

# %% [markdown]
# Neither hemisphere display strong correlations between wind speeds and latitudes. Scores indicate that the variability cannot be predicted by the line of best fit.
