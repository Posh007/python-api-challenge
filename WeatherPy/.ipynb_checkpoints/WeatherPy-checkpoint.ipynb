# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import json
import urllib
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %%
#OpenWeatherMap API Key
api_key = weather_api_key

#starting URL for Weather map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Define empty lists to store values

city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

#Print to logger
print("Beginning Data Retrieval")
print("------------------------")

#Create counters
record_count = 1
set_count = 1

#Looping through cities to make api calls using city as query
#Loop through all cities in out list
i = 1
for city in cities:
    city=city
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    
    
#Extracting data. Missing data is handled by try and except  
    try:
        city_name.append(response["name"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]['temp_max'])
        humidity.append(response["main"]['humidity'])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"]) 
        print(f"Processing record {i}|{city}")
        i+=1
         
    except (KeyError):
        print("City not found. skipping.")
    
print('''
-----------------------------
Data Retrieval Complete
-----------------------------''')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing record 1|rikitea
# Processing record 2|carnarvon
# City not found. skipping.
# Processing record 3|georgetown
# Processing record 4|syamzha
# Processing record 5|punta arenas
# Processing record 6|aklavik
# Processing record 7|emba
# Processing record 8|mataura
# City not found. skipping.
# Processing record 9|ponta do sol
# Processing record 10|thompson
# Processing record 11|fairbanks
# Processing record 12|bluff
# City not found. skipping.
# Processing record 13|ahipara
# Processing record 14|busselton
# Processing record 15|atuona
# Processing record 16|saldanha
# Processing record 17|ibra
# Processing record 18|mahebourg
# Processing record 19|butaritari
# Processing record 20|hobart
# Processing record 21|tasiilaq
# Processing record 22|tecalitlan
# Processing record 23|schladming
# Processing record 24|nuuk
# Processing record 25|auki
# Processing record 26|lagoa
# Processing record 27|portland
# Processing record 28|guaranda
# Processing record 29|comodoro rivadavia
# Processing record 30|khatanga
# Processing record 31|hithadhoo
# Processing record 32|nikolskoye
# Processing record 33|tarnogskiy gorodok
# Processing record 34|brasilia
# Processing record 35|port hardy
# City not found. skipping.
# Processing record 36|lavrentiya
# Processing record 37|aguada de pasajeros
# Processing record 38|ushuaia
# Processing record 39|provideniya
# Processing record 40|sao filipe
# Processing record 41|iskateley
# Processing record 42|talnakh
# City not found. skipping.
# City not found. skipping.
# Processing record 43|ballina
# Processing record 44|zhigansk
# Processing record 45|balkanabat
# Processing record 46|shache
# Processing record 47|soyo
# Processing record 48|tukrah
# Processing record 49|kot diji
# Processing record 50|uberaba
# Processing record 51|kapaa
# Processing record 52|komsomolskiy
# Processing record 53|cidreira
# City not found. skipping.
# Processing record 54|gersthofen
# Processing record 55|dikson
# Processing record 56|port elizabeth
# Processing record 57|saskylakh
# Processing record 58|vila franca do campo
# Processing record 59|yongan
# Processing record 60|rocha
# Processing record 61|solwezi
# City not found. skipping.
# City not found. skipping.
# Processing record 62|jamestown
# City not found. skipping.
# Processing record 63|ola
# Processing record 64|new norfolk
# Processing record 65|tuktoyaktuk
# Processing record 66|honiara
# Processing record 67|yellowknife
# Processing record 68|avarua
# Processing record 69|east london
# Processing record 70|albany
# Processing record 71|hilo
# Processing record 72|longyearbyen
# Processing record 73|souillac
# Processing record 74|northam
# Processing record 75|lukhovitsy
# Processing record 76|akhmim
# Processing record 77|aswan
# Processing record 78|waitati
# Processing record 79|djenne
# Processing record 80|ayorou
# Processing record 81|katherine
# Processing record 82|hammond
# City not found. skipping.
# Processing record 83|pevek
# Processing record 84|sioux lookout
# Processing record 85|saint-philippe
# Processing record 86|vaini
# Processing record 87|pangnirtung
# Processing record 88|bredasdorp
# Processing record 89|nanortalik
# Processing record 90|maningrida
# Processing record 91|thaton
# Processing record 92|cockburn town
# Processing record 93|virginia beach
# Processing record 94|puri
# Processing record 95|severo-kurilsk
# Processing record 96|pokrovsk
# City not found. skipping.
# Processing record 97|namibe
# City not found. skipping.
# Processing record 98|ambunti
# Processing record 99|soldotna
# Processing record 100|madison heights
# Processing record 101|shenjiamen
# Processing record 102|tual
# Processing record 103|dunedin
# Processing record 104|orje
# Processing record 105|mao
# Processing record 106|chuy
# City not found. skipping.
# Processing record 107|mar del plata
# Processing record 108|torbay
# Processing record 109|bambous virieux
# Processing record 110|winnemucca
# Processing record 111|katsuura
# Processing record 112|manggar
# Processing record 113|shihezi
# Processing record 114|new iberia
# Processing record 115|flin flon
# Processing record 116|saint-georges
# Processing record 117|mianyang
# Processing record 118|fortuna
# Processing record 119|zhanakorgan
# Processing record 120|havre-saint-pierre
# Processing record 121|jiayuguan
# Processing record 122|walvis bay
# City not found. skipping.
# Processing record 123|padang
# Processing record 124|broken hill
# Processing record 125|hamilton
# Processing record 126|labuhan
# Processing record 127|tursunzoda
# Processing record 128|hermanus
# Processing record 129|muroto
# Processing record 130|verkhnyaya inta
# Processing record 131|creel
# Processing record 132|petukhovo
# Processing record 133|norman wells
# Processing record 134|sao joao da barra
# Processing record 135|kirakira
# Processing record 136|nabire
# Processing record 137|bintulu
# Processing record 138|qaanaaq
# Processing record 139|atambua
# City not found. skipping.
# City not found. skipping.
# Processing record 140|henties bay
# Processing record 141|araouane
# Processing record 142|tabou
# Processing record 143|kodiak
# Processing record 144|port lavaca
# Processing record 145|samarai
# Processing record 146|arraial do cabo
# Processing record 147|berlevag
# Processing record 148|kibaha
# Processing record 149|griffith
# Processing record 150|hovd
# Processing record 151|plopana
# City not found. skipping.
# Processing record 152|sanmenxia
# Processing record 153|lokosovo
# Processing record 154|clyde river
# Processing record 155|hasaki
# Processing record 156|ribeira grande
# City not found. skipping.
# Processing record 157|klaksvik
# Processing record 158|luderitz
# Processing record 159|raudeberg
# Processing record 160|aykhal
# Processing record 161|west bay
# Processing record 162|port-gentil
# Processing record 163|kahului
# Processing record 164|celestun
# Processing record 165|teya
# Processing record 166|flinders
# Processing record 167|urucara
# Processing record 168|los llanos de aridane
# City not found. skipping.
# Processing record 169|pithora
# Processing record 170|monschau
# City not found. skipping.
# Processing record 171|tuatapere
# Processing record 172|puerto ayora
# Processing record 173|rio branco do sul
# City not found. skipping.
# Processing record 174|roswell
# Processing record 175|eyl
# City not found. skipping.
# Processing record 176|lorengau
# City not found. skipping.
# Processing record 177|fayaoue
# Processing record 178|mount isa
# Processing record 179|cody
# Processing record 180|olafsvik
# Processing record 181|pell city
# Processing record 182|port alfred
# City not found. skipping.
# City not found. skipping.
# Processing record 183|alofi
# Processing record 184|codrington
# Processing record 185|scarborough
# Processing record 186|rupert
# Processing record 187|hambantota
# Processing record 188|college
# Processing record 189|sabla
# Processing record 190|saint-louis
# Processing record 191|broome
# Processing record 192|bathsheba
# Processing record 193|jalu
# Processing record 194|lebu
# Processing record 195|woodward
# Processing record 196|jacareacanga
# City not found. skipping.
# Processing record 197|suntar
# Processing record 198|baghdad
# Processing record 199|castro
# Processing record 200|galanta
# Processing record 201|baswa
# Processing record 202|romitan
# Processing record 203|barrow
# City not found. skipping.
# Processing record 204|rapid valley
# Processing record 205|cape town
# Processing record 206|helmsdale
# Processing record 207|kuching
# Processing record 208|bengkulu
# City not found. skipping.
# Processing record 209|san lawrenz
# City not found. skipping.
# Processing record 210|sajanan
# Processing record 211|chadiza
# Processing record 212|safford
# Processing record 213|phan thiet
# Processing record 214|colquechaca
# City not found. skipping.
# Processing record 215|kruisfontein
# Processing record 216|constitucion
# Processing record 217|huarmey
# Processing record 218|emiliano zapata
# Processing record 219|upernavik
# Processing record 220|kaitangata
# Processing record 221|montorio al vomano
# Processing record 222|saint-pierre
# Processing record 223|oga
# Processing record 224|sapulpa
# Processing record 225|coihaique
# Processing record 226|tabuk
# Processing record 227|dudinka
# Processing record 228|zhangye
# Processing record 229|murindo
# Processing record 230|beitbridge
# City not found. skipping.
# Processing record 231|port hedland
# Processing record 232|pervomayskiy
# Processing record 233|ambilobe
# Processing record 234|mayo
# Processing record 235|poum
# Processing record 236|youghal
# Processing record 237|staryy nadym
# Processing record 238|airai
# City not found. skipping.
# Processing record 239|faanui
# Processing record 240|leshukonskoye
# Processing record 241|beringovskiy
# Processing record 242|pandharpur
# Processing record 243|victoria
# Processing record 244|hefei
# Processing record 245|alice springs
# Processing record 246|kudahuvadhoo
# Processing record 247|bilibino
# Processing record 248|westport
# Processing record 249|korla
# Processing record 250|dhidhdhoo
# Processing record 251|watertown
# Processing record 252|luanda
# Processing record 253|villa bruzual
# Processing record 254|port lincoln
# Processing record 255|bilma
# Processing record 256|peniche
# Processing record 257|lulea
# Processing record 258|saint george
# Processing record 259|vanavara
# Processing record 260|vad
# Processing record 261|kununurra
# Processing record 262|limon
# Processing record 263|esperance
# Processing record 264|banda aceh
# City not found. skipping.
# Processing record 265|havelock
# Processing record 266|srednekolymsk
# Processing record 267|vostok
# Processing record 268|ixtapa
# Processing record 269|popondetta
# Processing record 270|tisul
# Processing record 271|roma
# Processing record 272|trairi
# Processing record 273|viedma
# Processing record 274|tiznit
# Processing record 275|doha
# Processing record 276|manacapuru
# Processing record 277|floresta
# Processing record 278|saint-francois
# City not found. skipping.
# Processing record 279|elverum
# Processing record 280|kanchanaburi
# Processing record 281|kurilsk
# Processing record 282|lugovoy
# Processing record 283|pasni
# Processing record 284|madang
# Processing record 285|grand gaube
# Processing record 286|barao de melgaco
# Processing record 287|irbil
# Processing record 288|san patricio
# Processing record 289|atagay
# Processing record 290|felanitx
# Processing record 291|maxixe
# Processing record 292|pithoragarh
# Processing record 293|abha
# Processing record 294|chara
# City not found. skipping.
# Processing record 295|carutapera
# Processing record 296|gushikawa
# Processing record 297|coahuayana
# Processing record 298|batticaloa
# City not found. skipping.
# Processing record 299|plyussa
# City not found. skipping.
# Processing record 300|lompoc
# Processing record 301|puerto del rosario
# Processing record 302|saint-joseph
# Processing record 303|altay
# Processing record 304|pakokku
# Processing record 305|severodvinsk
# Processing record 306|kurumkan
# Processing record 307|kavaratti
# Processing record 308|farsund
# Processing record 309|yashan
# Processing record 310|goundi
# Processing record 311|eureka
# Processing record 312|itarema
# Processing record 313|aldan
# Processing record 314|puerto madero
# Processing record 315|urengoy
# Processing record 316|healesville
# Processing record 317|harper
# Processing record 318|guerrero negro
# Processing record 319|trelew
# Processing record 320|yumen
# Processing record 321|murgab
# Processing record 322|bestobe
# Processing record 323|baymak
# Processing record 324|saint-augustin
# Processing record 325|maceio
# Processing record 326|nichinan
# Processing record 327|kaseda
# Processing record 328|tongchuan
# Processing record 329|biltine
# Processing record 330|vila velha
# Processing record 331|ingham
# Processing record 332|kenai
# Processing record 333|acapulco
# Processing record 334|vao
# Processing record 335|lipari
# Processing record 336|canyon
# Processing record 337|asau
# Processing record 338|vardo
# Processing record 339|rafai
# Processing record 340|mitsamiouli
# Processing record 341|kinablangan
# Processing record 342|kidal
# Processing record 343|turukhansk
# Processing record 344|namatanai
# Processing record 345|ukiah
# Processing record 346|cayenne
# Processing record 347|sasina
# Processing record 348|hervey bay
# Processing record 349|les cayes
# Processing record 350|mareeba
# Processing record 351|inuvik
# Processing record 352|pijijiapan
# Processing record 353|sitka
# City not found. skipping.
# Processing record 354|thai binh
# Processing record 355|lima
# Processing record 356|pitrufquen
# Processing record 357|tucurui
# Processing record 358|mwinilunga
# Processing record 359|tiksi
# Processing record 360|bethel
# Processing record 361|palmer
# Processing record 362|panguna
# Processing record 363|gamba
# Processing record 364|noumea
# Processing record 365|tezu
# Processing record 366|ancud
# Processing record 367|lamesa
# Processing record 368|shimoda
# Processing record 369|cedar city
# Processing record 370|la antigua
# City not found. skipping.
# City not found. skipping.
# Processing record 371|alugan
# Processing record 372|wattegama
# Processing record 373|russkaya polyana
# Processing record 374|lixourion
# Processing record 375|kangaatsiaq
# Processing record 376|sinazongwe
# Processing record 377|san jose
# Processing record 378|christchurch
# Processing record 379|mumford
# Processing record 380|cherskiy
# Processing record 381|okato
# Processing record 382|albury
# Processing record 383|axim
# Processing record 384|pussi
# City not found. skipping.
# Processing record 385|estacion coahuila
# Processing record 386|lerwick
# Processing record 387|kayseri
# Processing record 388|lermontovka
# Processing record 389|la palma
# Processing record 390|nagua
# Processing record 391|san quintin
# Processing record 392|leningradskiy
# City not found. skipping.
# Processing record 393|aksarka
# Processing record 394|pierre
# City not found. skipping.
# Processing record 395|bystryy istok
# Processing record 396|haines junction
# Processing record 397|tawang
# Processing record 398|marzuq
# Processing record 399|niksic
# Processing record 400|chokurdakh
# Processing record 401|deputatskiy
# Processing record 402|chenghai
# Processing record 403|thunder bay
# Processing record 404|lodja
# Processing record 405|tamandare
# Processing record 406|nelson bay
# City not found. skipping.
# Processing record 407|kindersley
# Processing record 408|bluefield
# Processing record 409|portree
# Processing record 410|camopi
# Processing record 411|feltre
# Processing record 412|yulara
# Processing record 413|matara
# Processing record 414|marawi
# Processing record 415|vila
# Processing record 416|augusto correa
# Processing record 417|clinton
# Processing record 418|dolores
# Processing record 419|qaqortoq
# Processing record 420|geraldton
# Processing record 421|khamanon
# Processing record 422|nekhayevskiy
# Processing record 423|wajir
# Processing record 424|gat
# Processing record 425|bandarbeyla
# Processing record 426|okha
# City not found. skipping.
# Processing record 427|mokhsogollokh
# City not found. skipping.
# Processing record 428|husavik
# Processing record 429|sturgis
# City not found. skipping.
# City not found. skipping.
# Processing record 430|soe
# Processing record 431|touros
# Processing record 432|zabol
# Processing record 433|gvarv
# Processing record 434|ontario
# Processing record 435|salto del guaira
# Processing record 436|vestmannaeyjar
# Processing record 437|damghan
# Processing record 438|half moon bay
# Processing record 439|santiago
# Processing record 440|sandwick
# Processing record 441|pisco
# Processing record 442|presidencia roque saenz pena
# Processing record 443|green river
# Processing record 444|prince rupert
# Processing record 445|santo antonio do ica
# Processing record 446|choma
# Processing record 447|plettenberg bay
# Processing record 448|qui nhon
# Processing record 449|sidi ali
# Processing record 450|tetouan
# Processing record 451|umea
# Processing record 452|lagos
# Processing record 453|bundaberg
# Processing record 454|san jeronimo
# Processing record 455|nisia floresta
# Processing record 456|basey
# Processing record 457|jieshi
# Processing record 458|yueyang
# Processing record 459|dawei
# Processing record 460|porto novo
# Processing record 461|fomboni
# Processing record 462|saint pete beach
# Processing record 463|solnechnyy
# Processing record 464|nouadhibou
# Processing record 465|mathbaria
# Processing record 466|isangel
# Processing record 467|siyabuswa
# Processing record 468|kavieng
# Processing record 469|sarakhs
# Processing record 470|manta
# Processing record 471|santona
# Processing record 472|ostrovnoy
# Processing record 473|iralaya
# Processing record 474|ilulissat
# Processing record 475|pieve di soligo
# Processing record 476|indramayu
# Processing record 477|mittagong
# Processing record 478|iqaluit
# Processing record 479|duobao
# City not found. skipping.
# City not found. skipping.
# Processing record 480|plainview
# Processing record 481|laguna
# Processing record 482|sorong
# Processing record 483|talcahuano
# Processing record 484|kieta
# Processing record 485|bafang
# Processing record 486|magalia
# Processing record 487|aksu
# Processing record 488|lucapa
# Processing record 489|kedrovyy
# Processing record 490|baykit
# Processing record 491|venado tuerto
# Processing record 492|sur
# Processing record 493|san carlos de bariloche
# Processing record 494|pacific grove
# Processing record 495|narsaq
# Processing record 496|yelatma
# Processing record 497|bonavista
# Processing record 498|nageshwari
# Processing record 499|cabedelo
# Processing record 500|dong hoi
# Processing record 501|juneau
# Processing record 502|miyako
# Processing record 503|maniitsoq
# Processing record 504|puerto leguizamo
# Processing record 505|sakaiminato
# Processing record 506|lang suan
# Processing record 507|prado
# Processing record 508|port macquarie
# Processing record 509|san cristobal
# Processing record 510|huai thalaeng
# Processing record 511|tecpan
# Processing record 512|tuapse
# Processing record 513|canchungo
# Processing record 514|beloha
# Processing record 515|kupang
# Processing record 516|sembe
# Processing record 517|mount gambier
# Processing record 518|pimentel
# Processing record 519|matay
# Processing record 520|katangli
# Processing record 521|ordu
# Processing record 522|krasnyy yar
# Processing record 523|krasnoselkup
# Processing record 524|qasigiannguit
# Processing record 525|rodrigues alves
# Processing record 526|cabo san lucas
# Processing record 527|dukat
# Processing record 528|caravelas
# Processing record 529|dharchula
# Processing record 530|puerto ayacucho
# City not found. skipping.
# Processing record 531|alice town
# Processing record 532|fort nelson
# Processing record 533|bartica
# Processing record 534|meadow lake
# Processing record 535|kamenka
# Processing record 536|andenes
# Processing record 537|paita
# Processing record 538|samarkand
# Processing record 539|berwick
# Processing record 540|arman
# Processing record 541|nizhniy kuranakh
# Processing record 542|cap malheureux
# Processing record 543|tiarei
# Processing record 544|mantua
# Processing record 545|kirkenaer
# Processing record 546|kalabo
# Processing record 547|novoagansk
# City not found. skipping.
# Processing record 548|salamanca
# Processing record 549|chicama
# Processing record 550|waddan
# Processing record 551|dingle
# Processing record 552|fuerte olimpo
# Processing record 553|pascagoula
# Processing record 554|port antonio
# Processing record 555|itoman
# City not found. skipping.
# Processing record 556|ha tinh
# Processing record 557|krutinka
# Processing record 558|syracuse
# Processing record 559|twin falls
# Processing record 560|asfi
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Turn appended lists into dictionary
weather_dict = {
                "City": cities,
                "Lat": lat,
                "Lng": lng,
                "Max Temp": max_temp,
                "Cloudiness": cloudiness,
                "Humidity": humidity, 
                "Wind Speed": wind_speed,
                "Country": country,
                "Date": date                       
               }
#Turn dictionary into dataframe
city_data = pd.DataFrame({k: pd.Series(l) for k, l in weather_dict.items()})


# export city_data into csv
export_csv = city_data.to_csv (output_data_file, index_label = "City_ID")

# display Dataframe head
city_data.head()
# Out:
#          City      Lat       Lng  Max Temp  Cloudiness  Humidity  Wind Speed  \
# 0     rikitea -23.1203 -134.9692     76.59       100.0      86.0       16.22
# 1   carnarvon -24.8667  113.6333     78.60       100.0      48.0       11.12
# 2     marcona   5.4112  100.3354     89.89        40.0      70.0        3.51
# 3  georgetown  60.0158   41.0614     65.35        65.0      68.0        9.75
# 4     syamzha -53.1500  -70.9167     37.51         0.0      87.0        9.40
#
#   Country          Date
# 0      PF  1.623046e+09
# 1      AU  1.623046e+09
# 2      MY  1.623046e+09
# 3      RU  1.623046e+09
# 4      CL  1.623046e+09

# %%
city_data.count()
# Out:
# City          614
# Lat           560
# Lng           560
# Max Temp      560
# Cloudiness    560
# Humidity      560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# drop all the rows in which any of the column contains null value.
city_data = city_data.dropna(how="any")
city_data.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Cloudiness    560
# Humidity      560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
#Exporting data to csv
city_data.to_csv("output_data/cities.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#set todat date
today_date = pd.to_datetime('today').date().strftime('%m/%d/%y')

#Set x and y values
x_values = city_data['Lat']
y_values = city_data['Max Temp']

# Create scatter plot for lats vs temp
plt.scatter(x_values, y_values, edgecolors='black')

#Set Labels
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.title(f"City Latitude vs. Max Temperature ({today_date})")

#save & show
plt.savefig('output_data/CityLatitudeVsMaxTemp.png')

# %% [markdown]
# After each plot, add a sentence or two explaining what the code is analyzing.
#
# The above scatterplot is analyzing temperature values as we move closer and further away from the equator. We can see that temps rise as we near 0˚ latitude (equatorial location)
# Highest temperature is found at 0 latitude and as the latidude increases or decreases, temperature drops.
# The Temperature (F) vs. Latitude plot shown above, which includes data from all cities, peaks at approximately 20-degrees latitude. The latitude values below that latitude show a possible linear relationship with temperature, and the latitude values above that latitude also show a possible linear relationship with temperature, with both trends ending at the same peak temperature and latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Set x and y values
x_values = city_data['Lat']
y_values = city_data['Humidity']

# Create scatter plot for lats vs temp
plt.scatter(x_values, y_values, edgecolors='black')

#Set Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"City Latitude vs. Humidity ({today_date})")

#style grid
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#save & show
plt.savefig('output_data/CityLatitudeVsHumidity.png')

# %% [markdown]
# The Humidity vs. Latitude plot shown above, which contains data from all cities, shows a relatively spread-out distribution of data points. There does not appear to be a relationship between humidity and latitude at first glance, but the humidity percentages seem to largely cluster above 50%. Polar regions have lower humidity and as latitude gets higher,humidity gets higher in southern hemisphere.he above scatterplot is analyzing humidity values as we move closer and further away from the equator. It looks like humidity levels are not clearly different near 0˚ latitude (equatorial location).

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Set x and y values
x_values = city_data['Lat']
y_values = city_data['Cloudiness']

# Create scatter plot for lats vs temp
plt.scatter(x_values, y_values, edgecolors='black')

#Set Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"City Latitude vs. Cloudiness ({today_date})")

#style grid
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#save & show
plt.savefig('output_data/CityLatitudeVsCloudiness.png')

# %% [markdown]
#  Cloudiness data is widely spread across the latitude. The scatterplot above does not appear to show a definitive relationship between cloud cover and geolocation.The Cloudiness vs. Latitude plot shown above, containing data from all cities, does not seem to show a relationship between cloudiness and city latitude. There seem to be some values for cloudiness that the points cluster along, noticeably 0, 20, 40, 75, 90, and 100, so those values may be rounded or categorized from some of the sources, and not represent continuous variables or measurements.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Set x and y values
x_values = city_data['Lat']
y_values = city_data['Wind Speed']

# Create scatter plot for lats vs temp
plt.scatter(x_values, y_values, edgecolors='black')

#Set Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"City Latitude vs. Wind Speed ({today_date})")

#style grid
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#save & show
plt.savefig('output_data/CityLatitudeVsWindSpeed.png')

# %% [markdown]
# Wind speed data is widely spread across the latitude.The Wind speed vs. Latitude plot, shown above for all cities, does not seem to show any relationship between wind speed and latitude. Most of the wind speed values are below about 25 mph, with only a few values above that wind speed limit.Another scatterplot of wind speeds and geolocation comparisons. Again, the data seems like there is no clear pattern for wind speed measured at distances from the equator.

# %% [markdown]
# ## Linear Regression

# %%
 def linear_reg_plot(df, title_name, y_column_name, y_label, file_name, xy):
    x_values = df['Lat']
    y_values = df[y_column_name]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.annotate(line_eq,xy,fontsize=15,color="red")
    plt.title(title_name)
    
    print(f"The r-squared is: {rvalue}")
    
    plt.savefig(file_name)

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = city_data.loc[city_data['Lat'] >= 0, :]
southern_hemisphere_df = city_data.loc[city_data['Lat'] < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Max Temp Vs Latitude Regression', 'Max Temp', 'Max Temp', 'output_data/NorthernMaxTempVsLatitudeReg.png', (10,0))
# Out:
# The r-squared is: -0.742042546948891

# %% [markdown]
# There is a strong negative correlation between latitude and max temperature for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Max Temp Vs Latitude Regression', 'Max Temp', 'Max Temp', 'output_data/SouthernMaxTempVsLatitudeReg.png', (-40,50))
# Out:
# The r-squared is: 0.7053864816264391

# %% [markdown]
# There is a moderate positive correlation between latitude and max temperature for southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Humidity Vs. Latitude Regression', 'Humidity', 'Humidity', 'output_data/NorthernHumidityVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: -0.01781126828372174

# %% [markdown]
# There is a moderate positive correlation between latitude and humidity for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Humidity Vs. Latitude Regression', 'Humidity', 'Humidity', 'output_data/SouthernHumidityVsLatitudeReg.png', (-50,20))
# Out:
# The r-squared is: 0.203114930915187

# %% [markdown]
# #There is a moderate positive correlation between latitude and humidity for southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Cloudiness Vs. Latitude Regression', 'Cloudiness', 'Cloudiness', 'output_data/NorthernCloudinessVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: -0.013677349397189004

# %% [markdown]
# There is a weak positive correlation between latitude and cloudiness for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Cloudiness Vs. Latitude Regression', 'Cloudiness', 'Cloudiness', 'output_data/SouthernCloudinessVsLatitudeReg.png', (-50,20))
# Out:
# The r-squared is: 0.022337444081687807

# %% [markdown]
# There is a weak positive correlation between latitude and cloudiness for southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Wind Speed Vs. Latitude Regression', 'Wind Speed', 'Wind Speed', 'output_data/NorthernWindSpeedVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: -0.049414028657209993

# %% [markdown]
# There is a weak positive correlation between latitude and windspeed for northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Wind Speed Vs. Latitude', 'Wind Speed', 'Wind Speed', 'output_data/SouthernWindSpeedVsLatitudeReg.png', (-30,20))
# Out:
# The r-squared is: -0.27408940588019837

# %% [markdown]
# There is a weak negative correlation between latitude and wind speed for southern hemisphere.
